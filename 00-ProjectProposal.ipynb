# %% [markdown]
# ### Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline.   This cell is for your reference only and is not needed in your report.
#
# **Scoring:** Out of $10$ points
#
# - Each Developing => $-1$ pts
# - Each Unsatisfactory/Missing => $-2$ pts
# 	- until the score is 0
#
# If students address the detailed feedback in a future checkpoint, they will **earn these points back**.
#
#
# |                   | Unsatisfactory                                                                                                                                                                                                                                                                                    | Developing                                                                                                                                                                                                                                                                                                                                   | Proficient                                                                                                                                                                                                                                                    | Excellent                                                                                                                                                                                                                                                                                                                      |
# |-------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Research question | The research issue remains unclear. The research purpose, questions, hypotheses, definitions variables, and controls are still largely undefined, or when they are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | The research issue is identified, but the statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables, and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported by the research and theoretical literature. All elements are mutually supportive. |
# | Background        | Did not have at least 2 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                         | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                                    | Key research components were connected to relevant, reliable theoretical and research literature.                                                                                                                                                             | The narrative integrates critical and logical details from the peer-reviewed theoretical and research literature. Each key research component is grounded in the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                      |
# | Hypothesis        | Lacks most details; vague or interpretable in different ways. Or seems completely unrealistic.                                                                                                                                                                                                    | A key detail to understand the hypothesis or the rationale behind it was not described well enough                                                                                                                                                                                                                                           | The hypothesis is clear. All elements needed to understand the rationale were described in sufficient detail                                                                                                                                                  | The hypothesis and its rationale were described succinctly and with clarity about how they are connected to each other                                                                                                                                                                                                         |
# | Data              | Did not describe ideal dataset fully AND does not include at least one reference to an external source of data.                                                                                                                                                                         | Either does not describe the ideal dataset fully AND does not include at least one reference to an external source of data that could be used to answer the proposed question.                                                                                                                                                                                                                                                            | Ideal dataset(s) well-described and includes everything needed for answering question(s) posed. Includes at least one reference to a source of data that would be needed to fully answer the question proposed.                                                                                                                                                            | Ideal dataset(s) well-described and includes everything needed for answering question(s) posed. Includes references to all sources of data that would be needed to fully answer the question proposed. The details of the descriptions also make it clear how they support the needs of the project and discuss the differences betweeen the ideal and real datasets.                                                                                                                       |
# | Ethics            | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                                                          | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                               | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Team expectations | Lack of expectations                                                                                                                                                                                                                                                                              | The list of expectations feels incomplete and perfunctory                                                                                                                                                                                                                                                                                    | It feels like the list of expectations is complete and seems appropriate                                                                                                                                                                                      | The list clearly was the subject of a thoughtful approach and already indicates a well-working team                                                                                                                                                                                                                            |
# | Timeline          | Lack of timeline. Or timeline is completely unrealistic                                                                                                                                                                                                                                           | The timeline feels incomplete and perfunctory. The timeline feels either too fast or too slow for the progress you expect a group can make                                                                                                                                                                                                   | It feels like the timeline is complete and appropriate. it can likely be completed as is in the available amount of time                                                                                                                                      | The timeline was clearly the subject of a thoughtful approach and indicates that the team has a detailed plan that seems appropriate and completeable in the allotted time.                                                                                                                                                    |

# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# Team list and Credits:
# - Hanna Sun: Background Research, Conceptualization, Project Administration, Writing - original draft
# - Emerson Chen: Data curation, Experimental investigation, Methodology
# - Michael Lu:  Ethics
# - Marcus Lacuesta: Team Expectations

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a statistically significant relationship between recent win/loss outcomes and continuous play session length in competitive Valorant players? Additionally, can match outcome patterns be used to predict when a player is likely to stop playing?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Competitive online video games such as Valorant, a team-based first-person-shooter, provide a natural setting to study how reward and failure influence persistence. Wins and losses are not merely outcomes of play; they engage reinforcement learning mechanisms supported by dopaminergic reward signaling. A common misconception of dopamine is that dopamine neurons always activate upon receiving positive rewards. However, research in Reward Prediction Error (RPE) shows that dopamine neurons don't just respond to any reward: they respond only to rewards that differ from their prediction.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Take food, for example: you realize the dining hall just added your favourite food to the menu, so you ecstatically purchase it. Perhaps the next day, you'll get it again. But if you continue to buy it every single day, for 3 meals a day, for an entire month—you'll probably be sick of it, despite it having been your favourite food. The same applies in games—if you only ever win, at some point you'll get sick of it and quit.
#
# RPE suggests that unexpected outcomes can shape motivation and prolong engagement, but that still requires the right amount of variability in reinforcement schedules. Just as winning too much can dull your gameplay experience, losing too much could deter you from wanting to experience more. Most players believe that competitive MMR (Matchmaking Rating) systems aim for players to have roughly a 50% win/loss ratio, as "it means it's where you should be," (in terms of rank and skill) but some have also noted that it also creates negative feelings caused by being "hardstuck," <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). a phenomenon where players reach a bottleneck in terms of win/loss ratio, resulting in stagnant rankings that can contribute to feelings of demotivation. Hence, there is reason to suspect that MMR systems are not so transparently "50/50."
#
# Prior works show that there is a temporal attractiveness in uncertainty and resolution—uncertainty is worth it because resolution awaits<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). Our desire to move from a state of "unknown" to "knowing" is in itself valuable, regardless of whether the outcome is positive or negative. This added value of uncertainty is coined "resolution utility," (Ruan et al., 2018, Shen et al., 2019) <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3), and is crucial to why player's don't "quit halfway." The result of this research not only provides reasons for why continuous gameplay occurs, it also helps validate that a player's decision to stop playing is determined by what happens after resolution, rather than issues arising during gameplay.
#
# We specifically chose competitive Valorant because the added layer of social rewards in tandem with wins/losses will provide a stronger reinforcement effect. Competitive Valorant segregates players by skill, resulting in increasing game difficulty as the player improves, thereby ensuring that reward outcomes continue to be variable in nature<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). The rank labels displayed on player accounts introduce social status and evaluation, which can increase motivation to continue playing and make the decision to stop a more consequential choice.
#
# We recognize that ending a gaming session may come from a variety of reasons: fatigue, obligations (e.g., work or school), social factors, technical interruptions, and more. However, this project focuses on whether match outcome patterns have a statistically meaningful relationship with variation in play duration, which, if found, would indicate cause beyond these background factors.
#
# In summary, this project asks whether win–loss patterns correlate with continuous play duration in competitive Valorant. If such relationship is found, we then ask whether we are able to predict
#
# **References:**
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Schultz W. (2016). Dopamine reward prediction error coding. *Dialogues in clinical neuroscience*, 18(1), 23–32. https://doi.org/10.31887/DCNS.2016.18.1/wschultz
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Clark, L. & Zack, M. (2016) DEngineered highs: Reward variability and frequency as potential prerequisites of behavioural addiction *Addictive Behaviors*, Volume 140, 107626. https://doi.org/10.1016/j.addbeh.2023.107626.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Ruan, B., Hsee, C. K., & Lu, Z. Y. (2018). The Teasing Effect: An Underappreciated Benefit of Creating and Resolving an Uncertainty. *Journal of Marketing Research*, 55(4), 556-570. https://doi.org/10.1509/jmr.15.0346
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Necrachilles (2023). Should Comp RR Win/Loss Ratio Be Adjusted?. *Reddit*, r/VALORANT). https://www.reddit.com/r/VALORANT/comments/11py6bw/should_comp_rr_winloss_ratio_be_adjusted/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We believe that there is a strong relationship between win/loss outcomes and continuous play duration in competitive Valorant. We predict that players will tend to play longer after losses or alternating win–loss streaks compared to consistent winning outcomes, reflecting loss aversion and variable reinforcement effects. Because ranked games involve both dopaminergic reward feedback and social motivation through visible rank, we expect these outcome patterns to increase player persistence within a session.
#
# However, we also predict that extended loss streaks (e.g., beyond ~5 consecutive losses) will be associated with session termination, as sustained negative outcomes reduce rewarding feedback and may increase frustration, fatigue, and disengagement over time.

# %% [markdown]
# ## Data

# %% [markdown]
# Our dataset would require match timestamps to determine consecutive gameplay (which would act as out independent variable), and match outcomes to evaluate win/loss streak effects (our dependent variable). In an ideal dataset, we would also have various control variables including player rank (to control for skill variation), game mode (ranked vs. casual), match duration (to account for fatigue and time constraints), and party information (playing with friends vs. alone). These factors may influence both outcome and persistence, so controlling them would increase the validity of our analysis.
#
# Because win/loss patterns occur over repeated matches, in the most ideal situation, we would collect thousands of matches across many players. For example, a dataset of ~50–100 players with several hundred matches each (10,000+ total matches) would provide enough statistical power to examine session-level relationships and variability across individuals.
#
# Our goal is to collect data through official game analytics API rather than web-scraping (which may pose ethical concerns). This should provide us with the necessary amount of structure and detail for our analysis. However, we want to note that achieving a large dataset through this method may be difficult. Match history is only accessible by direct-search, meaning we would need consent from individual players to access their data.
#
# The data would be stored in a tidy, match-level format where each row represents one match played by one player. Columns would include player identifier, timestamp, win/loss outcome, match duration, and control variables such as rank or mode. Session-level features (e.g. streak length, session duration, matches per session) could then be derived during preprocessing and stored in a secondary aggregated dataset.
#
# Unfortunantely, there are only a few very limited publicly accessible dataset options that include several player's full timestamped match history information, however, thanks to free use APIs that recieve data directly from their source games, we can contruct our own dataset. A shared problem across all of these APIs is they they provide individual player information searched by an input player ID, therefore we will use an algorithm to randomly generate player IDs, check if those IDs are valid, then request the API for that player's data, ideally making a randomly selected dataset.
# Some potential APIs we could use are:
#
# [Marvel Rivals API on marvelrivalsapi.com](https://marvelrivalsapi.com/)
#  : This API is for the game Marvel Rivals. It requires having an account to use it, and a dynamic rate limit, which might make data collection harder, but other than that it's completely free use and follows the same data usage policy as Marvel Rivals itself so all player data on it is by default public and ethical to use. This API returns match history with full breakdowns of each game (the only relevant data from this is win or loss) organized by season and gamemode with timestamps which makes it fit all of our requirements, but it requires searching by player ID so we will have to do the random selection described before.
#
# [Apex Legends API on tracker.gg](https://tracker.gg/developers/docs/titles/apex)
#  : This API is for the game Apex Legends. It operates similarly to the previous API, but it doesn't require an account to use. This API follows Apex Legend's TOS, and by default has open profiles. Similar to the previous, this API returns individual player match history with wins and losses are recorded, but these match data are automatically grouped by "gaming sessions" which are periods of 45 minutes or longer spent playing consecutively.
#
# [Valorant tracker.gg scraper](https://github.com/sjerrietukkel/val_tracker_scraper)
#  : This github application is a data scraper for tracker.gg that will grab a player's last 200 Valorant matches. This scraper also searches by individual ID, similar to the other two, however it does very little data processing and the only relevant information it returns is the time the match is played and whether the match was won or lost, so it will be hard to estimate game session length since only the time is included and not the date the match is played. Furthermore, tracker.gg is against botting, so this scraper poses some ethical issues.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Although we are not directly collecting data from human subjects through surveys or experiments, we are collecting publicly available player statistics through official APIs provided by the game developers. Players did not explicitly provide consent to our specific project, so we will treat the data as potentially sensitive and avoid using it in ways that could harm individuals, such as targeting or profiling specific players.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# >  Data obtained from official game APIs may not represent all players equally. Some players may have private profiles, may not appear due to API limitations, or may be more likely to play ranked/competitive modes. This introduces selection bias and may overrepresent certain types of players, meaning our results may not generalize to the entire player population.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Player usernames, IDs, and account identifiers may count as personal identifiers because they can be linked back to individuals. We will avoid collecting unnecessary identifiers, and we will not publish raw usernames or IDs in our final report. If we need examples, we will anonymize them and focus on aggregated statistics rather than individual-level data
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Official game APIs generally do not provide demographic information such as race, gender, or age. Because of this, we cannot evaluate fairness across protected demographic groups. We will avoid making social conclusions beyond the scope of game performance data and will clearly communicate these limitations.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > We will store API-collected data locally or in a private repo environment only accessible to the project team. Since the dataset may contain player identifiers, we will avoid sharing raw scraped data publicly and instead publish cleaned/aggregated versions.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > We currently do not have an automated system for deletion requests. However, since this is a class project and the dataset is small, if a user requests removal, we can manually delete their records from our dataset.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > This dataset is only being collected for the duration of the course project. After the project is complete, we will delete the raw dataset containing player identifiers and retain only aggregated results or summary statistics if needed for documentation.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# > This project uses publicly available game performance data through official APIs. We are not directly engaging with players or stakeholders, so we may miss context such as differences in playstyle, region/platform differences, or reasons why players choose to be tracked. We will avoid making claims about “player skill” beyond what the statistics directly support.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > We acknowledge that biases may exist due to incomplete API coverage, differences across regions/platforms, and overrepresentation of competitive modes. We will report these limitations explicitly and avoid generalizing results beyond the dataset.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
# > We will avoid misleading charts and will clearly label sample sizes and filtering conditions. We will also include uncertainty or distribution information rather than relying only on averages.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > We will avoid exposing player usernames or unique identifiers in plots/tables. Analysis will focus on aggregated statistics (rank distributions, win rates, etc.) rather than profiling individual players.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > We will document the API usage, preprocessing pipeline, and modeling steps in our notebook/code. This ensures the analysis is reproducible and can be reviewed if issues or biases are discovered later.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
# > We are not building a model intended for decision-making about people, but we will still avoid interpreting correlations (ex: region/platform) in ways that imply unfair conclusions.
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > We do not have protected group attributes, so fairness testing is not feasible.
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# > We will consider that performance metrics like K/D ratio or win rate do not fully represent skill. We will compare multiple metrics and avoid ranking players using one metric alone.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed
# > Since we plan to use linear regression, our model is interpretable and explainable. Each feature has a coefficient that describes how changes in that feature are associated with changes in the predicted outcome (holding other variables constant). We will report coefficients and avoid using overly complex black-box models.
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# > We will include a limitations section explaining API coverage issues, missing demographic information, selection bias, and reasons why our conclusions may not generalize to all players.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
# > This is not a deployed system; it is a one-time analysis project.
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
# > We are not deploying a public-facing tool, but we will avoid publishing identifiable data that could harm individuals.
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
# > Not applicable since this is not a production system.
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > Player statistics could potentially be misused for harassment or targeted profiling. To reduce this risk, we will not publish raw datasets containing player identifiers and will focus on aggregated results in our final report.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# As a team we expect for each member to have active contribution to the work/project that we are all apart off, making sure that it is not just the work of one or two people. We expect to have clear and concise communication, whether it be through our main source of communication over Discord or some other facet. During this communication, we will all repsect each others opinions and thoughts on the topics we are working around, even if there may be some disagreements or discourse. We will strive to be accountable for each other, helping each other when it is needed, or even pushing each other when it is very needed. As a team we will try our best to stick to the timeline proposal, but knowing that each of our memebers have their own life and problems that they may be facing.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/29  |  3 PM | Brainstorm topics/questions, determine best form of communication  | Complete Assignment 1 Project Review; decide on final project topic; discuss hypothesis; begin background research |
# | 2/12  |  3 PM |  Finished project proposal, search for possible datasets | Decide on dataset (specific game might be different than proposal) and data collection method, decide on data sorting/cleaning methods |
# | 2/19  | 3 PM  | Complete data overview; Data Checkpoint Assignment submitted | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/26  | 3 PM  | Import & Wrangle Data | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 3/5  | 3 PM  | Finalize wrangling/EDA; Begin Analysis | Discuss/edit Analysis; Complete project check-in |
# | 3/12  | 3 PM  | Complete analysis; Draft results/conclusion/discussion| Discuss/edit full project |
# | 3/18  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
